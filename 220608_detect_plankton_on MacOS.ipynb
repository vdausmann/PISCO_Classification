# %% [markdown]
# # Detect plankton on MacOS with arm64 using Yolov5. (2022_06_08)
#
# Inference time with CoreML ~5s per image vs. about 25s per image with pytorch on CPU.
# Has to be started locally in your yolov5 directory.
#
# tested with torchvision == 0.14.0.dev20220603, torch == 1.13.0.dev20220607.

# %%
import csv
import cv2 as cv
import numpy as np
import os

# %% [markdown]
# 0. Export the pretrained weights (in this case yolov5l trained on copepods from CUSCO using colab with this notebook: https://github.com/DariGor/plancton_classifier/blob/main/Plankton_training_YOLOv5.ipynb) into the CoreML format. Important: choose the imagesize to match the images for detection and the data.yaml file of the original training data.

# %%
#%%capture
# !python export.py --weights best_colab_yolo5s_peru.pt --include coreml --imgsz 5120 --data data.yaml
#!python export.py --help
#!python export.py --weights best_colab_yolo5s_peru.pt --include coreml --imgsz 640 --conf-thres 0.4 --data data.yaml
# Out:
# export: data=data.yaml, weights=['best_colab_yolo5s_peru.pt'], imgsz=[5120], batch_size=1, device=cpu, half=False, inplace=False, train=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['coreml']
# YOLOv5 🚀 v6.2-80-g55b0096 Python-3.8.13 torch-1.13.0.dev20220831 CPU
#
# Fusing layers...
# Model summary: 224 layers, 7056607 parameters, 0 gradients
#
# PyTorch: starting from best_colab_yolo5s_peru.pt with output shape (1, 1612800, 7) (54.4 MB)
# TensorFlow version 2.9.2 has not been tested with coremltools. You may run into unexpected errors. TensorFlow 2.6.2 is the most recent version that has been tested.
# Keras version 2.9.0 has not been tested with coremltools. You may run into unexpected errors. Keras 2.6.0 is the most recent version that has been tested.
# Torch version 1.13.0.dev20220831 has not been tested with coremltools. You may run into unexpected errors. Torch 1.10.2 is the most recent version that has been tested.
#
# CoreML: starting export with coremltools 5.2.0...
# Tuple detected at graph output. This will be flattened in the converted model.
# Converting graph.
# Adding op 'model.0.conv.conv.bias' of type const
# Adding op 'model.0.conv.conv.weight' of type const
# Adding op 'model.1.conv.bias' of type const
# Adding op 'model.1.conv.weight' of type const
# Adding op 'model.2.cv1.conv.bias' of type const
# Adding op 'model.2.cv1.conv.weight' of type const
# Adding op 'model.2.m.0.cv1.conv.bias' of type const
# Adding op 'model.2.m.0.cv1.conv.weight' of type const
# Adding op 'model.2.m.0.cv2.conv.bias' of type const
# Adding op 'model.2.m.0.cv2.conv.weight' of type const
# Adding op 'model.2.cv2.conv.bias' of type const
# Adding op 'model.2.cv2.conv.weight' of type const
# Adding op 'model.2.cv3.conv.bias' of type const
# Adding op 'model.2.cv3.conv.weight' of type const
# Adding op 'model.3.conv.bias' of type const
# Adding op 'model.3.conv.weight' of type const
# Adding op 'model.4.cv1.conv.bias' of type const
# Adding op 'model.4.cv1.conv.weight' of type const
# Adding op 'model.4.m.0.cv1.conv.bias' of type const
# Adding op 'model.4.m.0.cv1.conv.weight' of type const
# Adding op 'model.4.m.0.cv2.conv.bias' of type const
# Adding op 'model.4.m.0.cv2.conv.weight' of type const
# Adding op 'model.4.m.1.cv1.conv.bias' of type const
# Adding op 'model.4.m.1.cv1.conv.weight' of type const
# Adding op 'model.4.m.1.cv2.conv.bias' of type const
# Adding op 'model.4.m.1.cv2.conv.weight' of type const
# Adding op 'model.4.m.2.cv1.conv.bias' of type const
# Adding op 'model.4.m.2.cv1.conv.weight' of type const
# Adding op 'model.4.m.2.cv2.conv.bias' of type const
# Adding op 'model.4.m.2.cv2.conv.weight' of type const
# Adding op 'model.4.cv2.conv.bias' of type const
# Adding op 'model.4.cv2.conv.weight' of type const
# Adding op 'model.4.cv3.conv.bias' of type const
# Adding op 'model.4.cv3.conv.weight' of type const
# Adding op 'model.5.conv.bias' of type const
# Adding op 'model.5.conv.weight' of type const
# Adding op 'model.6.cv1.conv.bias' of type const
# Adding op 'model.6.cv1.conv.weight' of type const
# Adding op 'model.6.m.0.cv1.conv.bias' of type const
# Adding op 'model.6.m.0.cv1.conv.weight' of type const
# Adding op 'model.6.m.0.cv2.conv.bias' of type const
# Adding op 'model.6.m.0.cv2.conv.weight' of type const
# Adding op 'model.6.m.1.cv1.conv.bias' of type const
# Adding op 'model.6.m.1.cv1.conv.weight' of type const
# Adding op 'model.6.m.1.cv2.conv.bias' of type const
# Adding op 'model.6.m.1.cv2.conv.weight' of type const
# Adding op 'model.6.m.2.cv1.conv.bias' of type const
# Adding op 'model.6.m.2.cv1.conv.weight' of type const
# Adding op 'model.6.m.2.cv2.conv.bias' of type const
# Adding op 'model.6.m.2.cv2.conv.weight' of type const
# Adding op 'model.6.cv2.conv.bias' of type const
# Adding op 'model.6.cv2.conv.weight' of type const
# Adding op 'model.6.cv3.conv.bias' of type const
# Adding op 'model.6.cv3.conv.weight' of type const
# Adding op 'model.7.conv.bias' of type const
# Adding op 'model.7.conv.weight' of type const
# Adding op 'model.8.cv1.conv.bias' of type const
# Adding op 'model.8.cv1.conv.weight' of type const
# Adding op 'model.8.cv2.conv.bias' of type const
# Adding op 'model.8.cv2.conv.weight' of type const
# Adding op 'model.9.cv1.conv.bias' of type const
# Adding op 'model.9.cv1.conv.weight' of type const
# Adding op 'model.9.m.0.cv1.conv.bias' of type const
# Adding op 'model.9.m.0.cv1.conv.weight' of type const
# Adding op 'model.9.m.0.cv2.conv.bias' of type const
# Adding op 'model.9.m.0.cv2.conv.weight' of type const
# Adding op 'model.9.cv2.conv.bias' of type const
# Adding op 'model.9.cv2.conv.weight' of type const
# Adding op 'model.9.cv3.conv.bias' of type const
# Adding op 'model.9.cv3.conv.weight' of type const
# Adding op 'model.10.conv.bias' of type const
# Adding op 'model.10.conv.weight' of type const
# Adding op 'model.13.cv1.conv.bias' of type const
# Adding op 'model.13.cv1.conv.weight' of type const
# Adding op 'model.13.m.0.cv1.conv.bias' of type const
# Adding op 'model.13.m.0.cv1.conv.weight' of type const
# Adding op 'model.13.m.0.cv2.conv.bias' of type const
# Adding op 'model.13.m.0.cv2.conv.weight' of type const
# Adding op 'model.13.cv2.conv.bias' of type const
# Adding op 'model.13.cv2.conv.weight' of type const
# Adding op 'model.13.cv3.conv.bias' of type const
# Adding op 'model.13.cv3.conv.weight' of type const
# Adding op 'model.14.conv.bias' of type const
# Adding op 'model.14.conv.weight' of type const
# Adding op 'model.17.cv1.conv.bias' of type const
# Adding op 'model.17.cv1.conv.weight' of type const
# Adding op 'model.17.m.0.cv1.conv.bias' of type const
# Adding op 'model.17.m.0.cv1.conv.weight' of type const
# Adding op 'model.17.m.0.cv2.conv.bias' of type const
# Adding op 'model.17.m.0.cv2.conv.weight' of type const
# Adding op 'model.17.cv2.conv.bias' of type const
# Adding op 'model.17.cv2.conv.weight' of type const
# Adding op 'model.17.cv3.conv.bias' of type const
# Adding op 'model.17.cv3.conv.weight' of type const
# Adding op 'model.18.conv.bias' of type const
# Adding op 'model.18.conv.weight' of type const
# Adding op 'model.20.cv1.conv.bias' of type const
# Adding op 'model.20.cv1.conv.weight' of type const
# Adding op 'model.20.m.0.cv1.conv.bias' of type const
# Adding op 'model.20.m.0.cv1.conv.weight' of type const
# Adding op 'model.20.m.0.cv2.conv.bias' of type const
# Adding op 'model.20.m.0.cv2.conv.weight' of type const
# Adding op 'model.20.cv2.conv.bias' of type const
# Adding op 'model.20.cv2.conv.weight' of type const
# Adding op 'model.20.cv3.conv.bias' of type const
# Adding op 'model.20.cv3.conv.weight' of type const
# Adding op 'model.21.conv.bias' of type const
# Adding op 'model.21.conv.weight' of type const
# Adding op 'model.23.cv1.conv.bias' of type const
# Adding op 'model.23.cv1.conv.weight' of type const
# Adding op 'model.23.m.0.cv1.conv.bias' of type const
# Adding op 'model.23.m.0.cv1.conv.weight' of type const
# Adding op 'model.23.m.0.cv2.conv.bias' of type const
# Adding op 'model.23.m.0.cv2.conv.weight' of type const
# Adding op 'model.23.cv2.conv.bias' of type const
# Adding op 'model.23.cv2.conv.weight' of type const
# Adding op 'model.23.cv3.conv.bias' of type const
# Adding op 'model.23.cv3.conv.weight' of type const
# Adding op 'model.24.m.0.bias' of type const
# Adding op 'model.24.m.0.weight' of type const
# Adding op 'model.24.m.1.bias' of type const
# Adding op 'model.24.m.1.weight' of type const
# Adding op 'model.24.m.2.bias' of type const
# Adding op 'model.24.m.2.weight' of type const
# Converting Frontend ==> MIL Ops:   0%|                | 0/620 [00:00<?, ? ops/s]Converting op 40 : constant
# Adding op '40' of type const
# Converting op 41 : constant
# Adding op '41' of type const
# Converting op 42 : constant
# Adding op '42' of type const
# Converting op 43 : constant
# Adding op '43' of type const
# Converting op 44 : constant
# Converting op 45 : constant
# Adding op '45' of type const
# Converting op 46 : constant
# Adding op '46' of type const
# Converting op 48 : slice
# Adding op '48' of type slice_by_index
# Adding op '48_begin_0' of type const
# Adding op '48_end_0' of type const
# Adding op '48_end_mask_0' of type const
# Adding op '48_stride_0' of type const
# Converting op 49 : slice
# Adding op '49' of type slice_by_index
# Adding op '49_begin_0' of type const
# Adding op '49_end_0' of type const
# Adding op '49_end_mask_0' of type const
# Adding op '49_stride_0' of type const
# Converting op 50 : slice
# Adding op '50' of type slice_by_index
# Adding op '50_begin_0' of type const
# Adding op '50_end_0' of type const
# Adding op '50_end_mask_0' of type const
# Adding op '50_stride_0' of type const
# Converting op 51 : slice
# Adding op '51' of type slice_by_index
# Adding op '51_begin_0' of type const
# Adding op '51_end_0' of type const
# Adding op '51_end_mask_0' of type const
# Adding op '51_stride_0' of type const
# Converting op 52 : slice
# Adding op '52' of type slice_by_index
# Adding op '52_begin_0' of type const
# Adding op '52_end_0' of type const
# Adding op '52_end_mask_0' of type const
# Adding op '52_stride_0' of type const
# Converting op 53 : slice
# Adding op '53' of type slice_by_index
# Adding op '53_begin_0' of type const
# Adding op '53_end_0' of type const
# Adding op '53_end_mask_0' of type const
# Adding op '53_stride_0' of type const
# Converting op 54 : slice
# Adding op '54' of type slice_by_index
# Adding op '54_begin_0' of type const
# Adding op '54_end_0' of type const
# Adding op '54_end_mask_0' of type const
# Adding op '54_stride_0' of type const
# Converting op 55 : slice
# Adding op '55' of type slice_by_index
# Adding op '55_begin_0' of type const
# Adding op '55_end_0' of type const
# Adding op '55_end_mask_0' of type const
# Adding op '55_stride_0' of type const
# Converting op 56 : listconstruct
# Converting op input.1 : cat
# Adding op 'input.1' of type concat
# Adding op 'input.1_interleave_0' of type const
# Converting op 61 : listconstruct
# Adding op '61' of type const
# Converting op 62 : listconstruct
# Adding op '62' of type const
# Converting op 63 : listconstruct
# Adding op '63' of type const
# Converting op 64 : listconstruct
# Adding op '64' of type const
# Converting op input.3 : _convolution
# Adding op 'input.3' of type conv
# Adding op 'input.3_pad_type_0' of type const
# Adding op 'input.3_pad_0' of type const
# Converting op input.5 : silu_
# Adding op 'input.5' of type silu
# Converting op 67 : constant
# Adding op '67' of type const
# Converting op 68 : constant
# Adding op '68' of type const
# Converting op 69 : constant
# Adding op '69' of type const
# Converting op 70 : constant
# Adding op '70' of type const
# Converting op 71 : constant
# Adding op '71' of type const
# Converting op 75 : listconstruct
# Adding op '75' of type const
# Converting op 76 : listconstruct
# Adding op '76' of type const
# Converting op 77 : listconstruct
# Adding op '77' of type const
# Converting op 78 : listconstruct
# Adding op '78' of type const
# Converting op input.7 : _convolution
# Adding op 'input.7' of type conv
# Adding op 'input.7_pad_type_0' of type const
# Adding op 'input.7_pad_0' of type const
# Converting op input.9 : silu_
# Adding op 'input.9' of type silu
# Converting op 81 : constant
# Adding op '81' of type const
# Converting op 82 : constant
# Adding op '82' of type const
# Converting op 83 : constant
# Adding op '83' of type const
# Converting op 84 : constant
# Adding op '84' of type const
# Converting op 92 : listconstruct
# Adding op '92' of type const
# Converting op 93 : listconstruct
# Adding op '93' of type const
# Converting op 94 : listconstruct
# Adding op '94' of type const
# Converting op 95 : listconstruct
# Adding op '95' of type const
# Converting op input.11 : _convolution
# Adding op 'input.11' of type conv
# Adding op 'input.11_pad_type_0' of type const
# Adding op 'input.11_pad_0' of type const
# Converting op input.13 : silu_
# Adding op 'input.13' of type silu
# Converting op 104 : listconstruct
# Adding op '104' of type const
# Converting op 105 : listconstruct
# Adding op '105' of type const
# Converting op 106 : listconstruct
# Adding op '106' of type const
# Converting op 107 : listconstruct
# Adding op '107' of type const
# Converting Frontend ==> MIL Ops:   8%|▍     | 48/620 [00:00<00:01, 479.83 ops/s]Converting op input.15 : _convolution
# Adding op 'input.15' of type conv
# Adding op 'input.15_pad_type_0' of type const
# Adding op 'input.15_pad_0' of type const
# Converting op input.17 : silu_
# Adding op 'input.17' of type silu
# Converting op 113 : listconstruct
# Adding op '113' of type const
# Converting op 114 : listconstruct
# Adding op '114' of type const
# Converting op 115 : listconstruct
# Adding op '115' of type const
# Converting op 116 : listconstruct
# Adding op '116' of type const
# Converting op input.19 : _convolution
# Adding op 'input.19' of type conv
# Adding op 'input.19_pad_type_0' of type const
# Adding op 'input.19_pad_0' of type const
# Converting op 118 : silu_
# Adding op '118' of type silu
# Converting op 119 : add
# Adding op '119' of type add
# Converting op 123 : listconstruct
# Adding op '123' of type const
# Converting op 124 : listconstruct
# Adding op '124' of type const
# Converting op 125 : listconstruct
# Adding op '125' of type const
# Converting op 126 : listconstruct
# Adding op '126' of type const
# Converting op input.21 : _convolution
# Adding op 'input.21' of type conv
# Adding op 'input.21_pad_type_0' of type const
# Adding op 'input.21_pad_0' of type const
# Converting op 128 : silu_
# Adding op '128' of type silu
# Converting op 129 : listconstruct
# Converting op input.23 : cat
# Adding op 'input.23' of type concat
# Adding op 'input.23_interleave_0' of type const
# Converting op 134 : listconstruct
# Adding op '134' of type const
# Converting op 135 : listconstruct
# Adding op '135' of type const
# Converting op 136 : listconstruct
# Adding op '136' of type const
# Converting op 137 : listconstruct
# Adding op '137' of type const
# Converting op input.25 : _convolution
# Adding op 'input.25' of type conv
# Adding op 'input.25_pad_type_0' of type const
# Adding op 'input.25_pad_0' of type const
# Converting op input.27 : silu_
# Adding op 'input.27' of type silu
# Converting op 140 : constant
# Adding op '140' of type const
# Converting op 141 : constant
# Adding op '141' of type const
# Converting op 142 : constant
# Adding op '142' of type const
# Converting op 143 : constant
# Adding op '143' of type const
# Converting op 144 : constant
# Adding op '144' of type const
# Converting op 148 : listconstruct
# Adding op '148' of type const
# Converting op 149 : listconstruct
# Adding op '149' of type const
# Converting op 150 : listconstruct
# Adding op '150' of type const
# Converting op 151 : listconstruct
# Adding op '151' of type const
# Converting op input.29 : _convolution
# Adding op 'input.29' of type conv
# Adding op 'input.29_pad_type_0' of type const
# Adding op 'input.29_pad_0' of type const
# Converting op input.31 : silu_
# Adding op 'input.31' of type silu
# Converting op 154 : constant
# Adding op '154' of type const
# Converting op 155 : constant
# Adding op '155' of type const
# Converting op 156 : constant
# Adding op '156' of type const
# Converting op 157 : constant
# Adding op '157' of type const
# Converting op 165 : listconstruct
# Adding op '165' of type const
# Converting op 166 : listconstruct
# Adding op '166' of type const
# Converting op 167 : listconstruct
# Adding op '167' of type const
# Converting op 168 : listconstruct
# Adding op '168' of type const
# Converting op input.33 : _convolution
# Adding op 'input.33' of type conv
# Adding op 'input.33_pad_type_0' of type const
# Adding op 'input.33_pad_0' of type const
# Converting op input.35 : silu_
# Adding op 'input.35' of type silu
# Converting op 179 : listconstruct
# Adding op '179' of type const
# Converting op 180 : listconstruct
# Adding op '180' of type const
# Converting op 181 : listconstruct
# Adding op '181' of type const
# Converting op 182 : listconstruct
# Adding op '182' of type const
# Converting op input.37 : _convolution
# Adding op 'input.37' of type conv
# Adding op 'input.37_pad_type_0' of type const
# Adding op 'input.37_pad_0' of type const
# Converting op input.39 : silu_
# Adding op 'input.39' of type silu
# Converting op 188 : listconstruct
# Adding op '188' of type const
# Converting op 189 : listconstruct
# Adding op '189' of type const
# Converting op 190 : listconstruct
# Adding op '190' of type const
# Converting op 191 : listconstruct
# Adding op '191' of type const
# Converting op input.41 : _convolution
# Adding op 'input.41' of type conv
# Adding op 'input.41_pad_type_0' of type const
# Adding op 'input.41_pad_0' of type const
# Converting op 193 : silu_
# Adding op '193' of type silu
# Converting op input.43 : add
# Adding op 'input.43' of type add
# Converting op 200 : listconstruct
# Adding op '200' of type const
# Converting op 201 : listconstruct
# Adding op '201' of type const
# Converting op 202 : listconstruct
# Adding op '202' of type const
# Converting op 203 : listconstruct
# Adding op '203' of type const
# Converting op input.45 : _convolution
# Adding op 'input.45' of type conv
# Adding op 'input.45_pad_type_0' of type const
# Adding op 'input.45_pad_0' of type const
# Converting op input.47 : silu_
# Adding op 'input.47' of type silu
# Converting op 209 : listconstruct
# Adding op '209' of type const
# Converting op 210 : listconstruct
# Adding op '210' of type const
# Converting op 211 : listconstruct
# Adding op '211' of type const
# Converting op 212 : listconstruct
# Adding op '212' of type const
# Converting op input.49 : _convolution
# Adding op 'input.49' of type conv
# Adding op 'input.49_pad_type_0' of type const
# Adding op 'input.49_pad_0' of type const
# Converting op 214 : silu_
# Adding op '214' of type silu
# Converting op input.51 : add
# Adding op 'input.51' of type add
# Converting op 221 : listconstruct
# Adding op '221' of type const
# Converting op 222 : listconstruct
# Adding op '222' of type const
# Converting op 223 : listconstruct
# Adding op '223' of type const
# Converting op 224 : listconstruct
# Adding op '224' of type const
# Converting op input.53 : _convolution
# Adding op 'input.53' of type conv
# Adding op 'input.53_pad_type_0' of type const
# Adding op 'input.53_pad_0' of type const
# Converting op input.55 : silu_
# Adding op 'input.55' of type silu
# Converting op 230 : listconstruct
# Adding op '230' of type const
# Converting op 231 : listconstruct
# Adding op '231' of type const
# Converting op 232 : listconstruct
# Adding op '232' of type const
# Converting op 233 : listconstruct
# Adding op '233' of type const
# Converting op input.57 : _convolution
# Adding op 'input.57' of type conv
# Adding op 'input.57_pad_type_0' of type const
# Adding op 'input.57_pad_0' of type const
# Converting op 235 : silu_
# Adding op '235' of type silu
# Converting op 236 : add
# Adding op '236' of type add
# Converting op 240 : listconstruct
# Adding op '240' of type const
# Converting op 241 : listconstruct
# Adding op '241' of type const
# Converting op 242 : listconstruct
# Adding op '242' of type const
# Converting op 243 : listconstruct
# Adding op '243' of type const
# Converting op input.59 : _convolution
# Adding op 'input.59' of type conv
# Adding op 'input.59_pad_type_0' of type const
# Adding op 'input.59_pad_0' of type const
# Converting op 245 : silu_
# Adding op '245' of type silu
# Converting op 246 : listconstruct
# Converting op input.61 : cat
# Adding op 'input.61' of type concat
# Adding op 'input.61_interleave_0' of type const
# Converting op 251 : listconstruct
# Adding op '251' of type const
# Converting op 252 : listconstruct
# Adding op '252' of type const
# Converting op 253 : listconstruct
# Adding op '253' of type const
# Converting op 254 : listconstruct
# Adding op '254' of type const
# Converting op input.63 : _convolution
# Adding op 'input.63' of type conv
# Adding op 'input.63_pad_type_0' of type const
# Adding op 'input.63_pad_0' of type const
# Converting op input.65 : silu_
# Adding op 'input.65' of type silu
# Converting op 257 : constant
# Adding op '257' of type const
# Converting op 258 : constant
# Adding op '258' of type const
# Converting op 259 : constant
# Adding op '259' of type const
# Converting op 260 : constant
# Adding op '260' of type const
# Converting op 261 : constant
# Adding op '261' of type const
# Converting op 265 : listconstruct
# Adding op '265' of type const
# Converting op 266 : listconstruct
# Adding op '266' of type const
# Converting op 267 : listconstruct
# Adding op '267' of type const
# Converting op 268 : listconstruct
# Adding op '268' of type const
# Converting op input.67 : _convolution
# Adding op 'input.67' of type conv
# Adding op 'input.67_pad_type_0' of type const
# Adding op 'input.67_pad_0' of type const
# Converting op input.69 : silu_
# Adding op 'input.69' of type silu
# Converting op 271 : constant
# Adding op '271' of type const
# Converting op 272 : constant
# Adding op '272' of type const
# Converting op 273 : constant
# Adding op '273' of type const
# Converting op 274 : constant
# Adding op '274' of type const
# Converting op 282 : listconstruct
# Adding op '282' of type const
# Converting op 283 : listconstruct
# Adding op '283' of type const
# Converting op 284 : listconstruct
# Adding op '284' of type const
# Converting op 285 : listconstruct
# Adding op '285' of type const
# Converting op input.71 : _convolution
# Adding op 'input.71' of type conv
# Adding op 'input.71_pad_type_0' of type const
# Adding op 'input.71_pad_0' of type const
# Converting op input.73 : silu_
# Adding op 'input.73' of type silu
# Converting op 296 : listconstruct
# Adding op '296' of type const
# Converting op 297 : listconstruct
# Adding op '297' of type const
# Converting op 298 : listconstruct
# Adding op '298' of type const
# Converting op 299 : listconstruct
# Adding op '299' of type const
# Converting op input.75 : _convolution
# Adding op 'input.75' of type conv
# Adding op 'input.75_pad_type_0' of type const
# Adding op 'input.75_pad_0' of type const
# Converting op input.77 : silu_
# Adding op 'input.77' of type silu
# Converting op 305 : listconstruct
# Adding op '305' of type const
# Converting op 306 : listconstruct
# Adding op '306' of type const
# Converting op 307 : listconstruct
# Adding op '307' of type const
# Converting op 308 : listconstruct
# Adding op '308' of type const
# Converting op input.79 : _convolution
# Adding op 'input.79' of type conv
# Adding op 'input.79_pad_type_0' of type const
# Adding op 'input.79_pad_0' of type const
# Converting op 310 : silu_
# Adding op '310' of type silu
# Converting op input.81 : add
# Adding op 'input.81' of type add
# Converting op 317 : listconstruct
# Adding op '317' of type const
# Converting op 318 : listconstruct
# Adding op '318' of type const
# Converting op 319 : listconstruct
# Adding op '319' of type const
# Converting op 320 : listconstruct
# Adding op '320' of type const
# Converting op input.83 : _convolution
# Adding op 'input.83' of type conv
# Adding op 'input.83_pad_type_0' of type const
# Adding op 'input.83_pad_0' of type const
# Converting op input.85 : silu_
# Adding op 'input.85' of type silu
# Converting op 326 : listconstruct
# Adding op '326' of type const
# Converting op 327 : listconstruct
# Adding op '327' of type const
# Converting op 328 : listconstruct
# Adding op '328' of type const
# Converting op 329 : listconstruct
# Adding op '329' of type const
# Converting op input.87 : _convolution
# Adding op 'input.87' of type conv
# Adding op 'input.87_pad_type_0' of type const
# Adding op 'input.87_pad_0' of type const
# Converting op 331 : silu_
# Adding op '331' of type silu
# Converting op input.89 : add
# Adding op 'input.89' of type add
# Converting op 338 : listconstruct
# Adding op '338' of type const
# Converting op 339 : listconstruct
# Adding op '339' of type const
# Converting op 340 : listconstruct
# Adding op '340' of type const
# Converting op 341 : listconstruct
# Adding op '341' of type const
# Converting op input.91 : _convolution
# Adding op 'input.91' of type conv
# Adding op 'input.91_pad_type_0' of type const
# Adding op 'input.91_pad_0' of type const
# Converting op input.93 : silu_
# Adding op 'input.93' of type silu
# Converting op 347 : listconstruct
# Adding op '347' of type const
# Converting op 348 : listconstruct
# Adding op '348' of type const
# Converting op 349 : listconstruct
# Adding op '349' of type const
# Converting op 350 : listconstruct
# Adding op '350' of type const
# Converting op input.95 : _convolution
# Adding op 'input.95' of type conv
# Adding op 'input.95_pad_type_0' of type const
# Adding op 'input.95_pad_0' of type const
# Converting op 352 : silu_
# Adding op '352' of type silu
# Converting op 353 : add
# Adding op '353' of type add
# Converting op 357 : listconstruct
# Adding op '357' of type const
# Converting op 358 : listconstruct
# Adding op '358' of type const
# Converting op 359 : listconstruct
# Adding op '359' of type const
# Converting op 360 : listconstruct
# Adding op '360' of type const
# Converting op input.97 : _convolution
# Adding op 'input.97' of type conv
# Adding op 'input.97_pad_type_0' of type const
# Adding op 'input.97_pad_0' of type const
# Converting op 362 : silu_
# Adding op '362' of type silu
# Converting op 363 : listconstruct
# Converting op input.99 : cat
# Adding op 'input.99' of type concat
# Adding op 'input.99_interleave_0' of type const
# Converting op 368 : listconstruct
# Adding op '368' of type const
# Converting op 369 : listconstruct
# Adding op '369' of type const
# Converting op 370 : listconstruct
# Adding op '370' of type const
# Converting op 371 : listconstruct
# Adding op '371' of type const
# Converting op input.101 : _convolution
# Adding op 'input.101' of type conv
# Adding op 'input.101_pad_type_0' of type const
# Adding op 'input.101_pad_0' of type const
# Converting op input.103 : silu_
# Adding op 'input.103' of type silu
# Converting op 374 : constant
# Adding op '374' of type const
# Converting op 375 : constant
# Adding op '375' of type const
# Converting op 376 : constant
# Adding op '376' of type const
# Converting op 377 : constant
# Adding op '377' of type const
# Converting op 378 : constant
# Adding op '378' of type const
# Converting op 382 : listconstruct
# Adding op '382' of type const
# Converting op 383 : listconstruct
# Adding op '383' of type const
# Converting op 384 : listconstruct
# Adding op '384' of type const
# Converting op 385 : listconstruct
# Adding op '385' of type const
# Converting op input.105 : _convolution
# Adding op 'input.105' of type conv
# Adding op 'input.105_pad_type_0' of type const
# Adding op 'input.105_pad_0' of type const
# Converting op input.107 : silu_
# Adding op 'input.107' of type silu
# Converting op 388 : constant
# Adding op '388' of type const
# Converting op 389 : constant
# Adding op '389' of type const
# Converting op 390 : constant
# Adding op '390' of type const
# Converting op 391 : constant
# Adding op '391' of type const
# Converting op 392 : constant
# Adding op '392' of type const
# Converting op 393 : constant
# Adding op '393' of type const
# Converting op 394 : constant
# Adding op '394' of type const
# Converting op 395 : constant
# Adding op '395' of type const
# Converting op 396 : constant
# Adding op '396' of type const
# Converting op 397 : constant
# Adding op '397' of type const
# Converting op 403 : listconstruct
# Adding op '403' of type const
# Converting op 404 : listconstruct
# Adding op '404' of type const
# Converting op 405 : listconstruct
# Adding op '405' of type const
# Converting op 406 : listconstruct
# Adding op '406' of type const
# Converting op input.109 : _convolution
# Adding op 'input.109' of type conv
# Adding op 'input.109_pad_type_0' of type const
# Adding op 'input.109_pad_0' of type const
# Converting op input.111 : silu_
# Adding op 'input.111' of type silu
# Converting op 409 : listconstruct
# Adding op '409' of type const
# Converting op 410 : listconstruct
# Adding op '410' of type const
# Converting op 411 : listconstruct
# Adding op '411' of type const
# Converting op 412 : listconstruct
# Adding op '412' of type const
# Converting op 413 : max_pool2d
# Adding op '413' of type max_pool
# Adding op '413_pad_type_0' of type const
# Adding op '413_pad_0' of type const
# Adding op '413_ceil_mode_0' of type const
# Converting op 414 : listconstruct
# Adding op '414' of type const
# Converting op 415 : listconstruct
# Adding op '415' of type const
# Converting op 416 : listconstruct
# Adding op '416' of type const
# Converting op 417 : listconstruct
# Adding op '417' of type const
# Converting op 418 : max_pool2d
# Adding op '418' of type max_pool
# Adding op '418_pad_type_0' of type const
# Adding op '418_pad_0' of type const
# Adding op '418_ceil_mode_0' of type const
# Converting op 419 : listconstruct
# Adding op '419' of type const
# Converting op 420 : listconstruct
# Adding op '420' of type const
# Converting op 421 : listconstruct
# Adding op '421' of type const
# Converting op 422 : listconstruct
# Adding op '422' of type const
# Converting op 423 : max_pool2d
# Adding op '423' of type max_pool
# Adding op '423_pad_type_0' of type const
# Adding op '423_pad_0' of type const
# Adding op '423_ceil_mode_0' of type const
# Converting op 424 : listconstruct
# Converting op input.113 : cat
# Adding op 'input.113' of type concat
# Adding op 'input.113_interleave_0' of type const
# Converting op 429 : listconstruct
# Adding op '429' of type const
# Converting op 430 : listconstruct
# Adding op '430' of type const
# Converting op 431 : listconstruct
# Adding op '431' of type const
# Converting op 432 : listconstruct
# Adding op '432' of type const
# Converting op input.115 : _convolution
# Adding op 'input.115' of type conv
# Adding op 'input.115_pad_type_0' of type const
# Adding op 'input.115_pad_0' of type const
# Converting op input.117 : silu_
# Adding op 'input.117' of type silu
# Converting op 435 : constant
# Adding op '435' of type const
# Converting op 436 : constant
# Adding op '436' of type const
# Converting op 437 : constant
# Adding op '437' of type const
# Converting op 438 : constant
# Adding op '438' of type const
# Converting op 446 : listconstruct
# Adding op '446' of type const
# Converting op 447 : listconstruct
# Adding op '447' of type const
# Converting op 448 : listconstruct
# Adding op '448' of type const
# Converting op 449 : listconstruct
# Adding op '449' of type const
# Converting op input.119 : _convolution
# Adding op 'input.119' of type conv
# Adding op 'input.119_pad_type_0' of type const
# Adding op 'input.119_pad_0' of type const
# Converting op input.121 : silu_
# Adding op 'input.121' of type silu
# Converting op 458 : listconstruct
# Adding op '458' of type const
# Converting op 459 : listconstruct
# Adding op '459' of type const
# Converting op 460 : listconstruct
# Adding op '460' of type const
# Converting op 461 : listconstruct
# Adding op '461' of type const
# Converting op input.123 : _convolution
# Adding op 'input.123' of type conv
# Adding op 'input.123_pad_type_0' of type const
# Adding op 'input.123_pad_0' of type const
# Converting op input.125 : silu_
# Adding op 'input.125' of type silu
# Converting op 467 : listconstruct
# Adding op '467' of type const
# Converting op 468 : listconstruct
# Adding op '468' of type const
# Converting op 469 : listconstruct
# Adding op '469' of type const
# Converting op 470 : listconstruct
# Adding op '470' of type const
# Converting op input.127 : _convolution
# Adding op 'input.127' of type conv
# Adding op 'input.127_pad_type_0' of type const
# Adding op 'input.127_pad_0' of type const
# Converting op 472 : silu_
# Adding op '472' of type silu
# Converting op 476 : listconstruct
# Adding op '476' of type const
# Converting op 477 : listconstruct
# Adding op '477' of type const
# Converting op 478 : listconstruct
# Adding op '478' of type const
# Converting op 479 : listconstruct
# Adding op '479' of type const
# Converting op input.129 : _convolution
# Adding op 'input.129' of type conv
# Adding op 'input.129_pad_type_0' of type const
# Adding op 'input.129_pad_0' of type const
# Converting op 481 : silu_
# Adding op '481' of type silu
# Converting op 482 : listconstruct
# Converting op input.131 : cat
# Adding op 'input.131' of type concat
# Adding op 'input.131_interleave_0' of type const
# Converting op 487 : listconstruct
# Adding op '487' of type const
# Converting op 488 : listconstruct
# Adding op '488' of type const
# Converting op 489 : listconstruct
# Adding op '489' of type const
# Converting op 490 : listconstruct
# Adding op '490' of type const
# Converting op input.133 : _convolution
# Adding op 'input.133' of type conv
# Adding op 'input.133_pad_type_0' of type const
# Adding op 'input.133_pad_0' of type const
# Converting op input.135 : silu_
# Adding op 'input.135' of type silu
# Converting op 493 : constant
# Adding op '493' of type const
# Converting op 494 : constant
# Adding op '494' of type const
# Converting op 495 : constant
# Adding op '495' of type const
# Converting op 496 : constant
# Adding op '496' of type const
# Converting op 500 : listconstruct
# Adding op '500' of type const
# Converting op 501 : listconstruct
# Adding op '501' of type const
# Converting op 502 : listconstruct
# Adding op '502' of type const
# Converting op 503 : listconstruct
# Adding op '503' of type const
# Converting op input.137 : _convolution
# Adding op 'input.137' of type conv
# Adding op 'input.137_pad_type_0' of type const
# Adding op 'input.137_pad_0' of type const
# Converting op input.139 : silu_
# Adding op 'input.139' of type silu
# Converting op 506 : constant
# Adding op '506' of type const
# Converting op 507 : constant
# Converting op 508 : listconstruct
# Adding op '508' of type const
# Converting op 509 : upsample_nearest2d
# Adding op '509' of type upsample_nearest_neighbor
# Adding op '509_scale_factor_height_0' of type const
# Adding op '509_scale_factor_width_0' of type const
# Converting op 510 : constant
# Adding op '510' of type const
# Converting op 511 : listconstruct
# Converting op input.141 : cat
# Adding op 'input.141' of type concat
# Adding op 'input.141_interleave_0' of type const
# Converting op 513 : constant
# Adding op '513' of type const
# Converting op 514 : constant
# Adding op '514' of type const
# Converting op 515 : constant
# Adding op '515' of type const
# Converting op 516 : constant
# Adding op '516' of type const
# Converting op 524 : listconstruct
# Adding op '524' of type const
# Converting op 525 : listconstruct
# Adding op '525' of type const
# Converting op 526 : listconstruct
# Adding op '526' of type const
# Converting op 527 : listconstruct
# Adding op '527' of type const
# Converting op input.143 : _convolution
# Adding op 'input.143' of type conv
# Adding op 'input.143_pad_type_0' of type const
# Adding op 'input.143_pad_0' of type const
# Converting op input.145 : silu_
# Adding op 'input.145' of type silu
# Converting op 536 : listconstruct
# Adding op '536' of type const
# Converting op 537 : listconstruct
# Adding op '537' of type const
# Converting op 538 : listconstruct
# Adding op '538' of type const
# Converting op 539 : listconstruct
# Adding op '539' of type const
# Converting op input.147 : _convolution
# Adding op 'input.147' of type conv
# Adding op 'input.147_pad_type_0' of type const
# Adding op 'input.147_pad_0' of type const
# Converting op input.149 : silu_
# Adding op 'input.149' of type silu
# Converting op 545 : listconstruct
# Adding op '545' of type const
# Converting op 546 : listconstruct
# Adding op '546' of type const
# Converting op 547 : listconstruct
# Adding op '547' of type const
# Converting op 548 : listconstruct
# Adding op '548' of type const
# Converting op input.151 : _convolution
# Adding op 'input.151' of type conv
# Adding op 'input.151_pad_type_0' of type const
# Adding op 'input.151_pad_0' of type const
# Converting op 550 : silu_
# Adding op '550' of type silu
# Converting op 554 : listconstruct
# Adding op '554' of type const
# Converting op 555 : listconstruct
# Adding op '555' of type const
# Converting op 556 : listconstruct
# Adding op '556' of type const
# Converting op 557 : listconstruct
# Adding op '557' of type const
# Converting op input.153 : _convolution
# Adding op 'input.153' of type conv
# Adding op 'input.153_pad_type_0' of type const
# Adding op 'input.153_pad_0' of type const
# Converting op 559 : silu_
# Adding op '559' of type silu
# Converting op 560 : listconstruct
# Converting op input.155 : cat
# Adding op 'input.155' of type concat
# Adding op 'input.155_interleave_0' of type const
# Converting op 565 : listconstruct
# Adding op '565' of type const
# Converting op 566 : listconstruct
# Adding op '566' of type const
# Converting op 567 : listconstruct
# Adding op '567' of type const
# Converting op 568 : listconstruct
# Adding op '568' of type const
# Converting op input.157 : _convolution
# Adding op 'input.157' of type conv
# Adding op 'input.157_pad_type_0' of type const
# Adding op 'input.157_pad_0' of type const
# Converting op input.159 : silu_
# Adding op 'input.159' of type silu
# Converting op 571 : constant
# Adding op '571' of type const
# Converting op 572 : constant
# Adding op '572' of type const
# Converting op 573 : constant
# Adding op '573' of type const
# Converting op 574 : constant
# Adding op '574' of type const
# Converting op 578 : listconstruct
# Adding op '578' of type const
# Converting op 579 : listconstruct
# Adding op '579' of type const
# Converting op 580 : listconstruct
# Adding op '580' of type const
# Converting op 581 : listconstruct
# Adding op '581' of type const
# Converting op input.161 : _convolution
# Adding op 'input.161' of type conv
# Adding op 'input.161_pad_type_0' of type const
# Adding op 'input.161_pad_0' of type const
# Converting op input.163 : silu_
# Adding op 'input.163' of type silu
# Converting op 584 : constant
# Adding op '584' of type const
# Converting op 585 : constant
# Converting op 586 : listconstruct
# Adding op '586' of type const
# Converting op 587 : upsample_nearest2d
# Adding op '587' of type upsample_nearest_neighbor
# Adding op '587_scale_factor_height_0' of type const
# Adding op '587_scale_factor_width_0' of type const
# Converting op 588 : constant
# Adding op '588' of type const
# Converting op 589 : listconstruct
# Converting op input.165 : cat
# Adding op 'input.165' of type concat
# Adding op 'input.165_interleave_0' of type const
# Converting op 591 : constant
# Adding op '591' of type const
# Converting op 592 : constant
# Adding op '592' of type const
# Converting op 593 : constant
# Adding op '593' of type const
# Converting op 594 : constant
# Adding op '594' of type const
# Converting op 602 : listconstruct
# Adding op '602' of type const
# Converting op 603 : listconstruct
# Adding op '603' of type const
# Converting op 604 : listconstruct
# Adding op '604' of type const
# Converting op 605 : listconstruct
# Adding op '605' of type const
# Converting op input.167 : _convolution
# Adding op 'input.167' of type conv
# Adding op 'input.167_pad_type_0' of type const
# Adding op 'input.167_pad_0' of type const
# Converting op input.169 : silu_
# Adding op 'input.169' of type silu
# Converting op 614 : listconstruct
# Adding op '614' of type const
# Converting op 615 : listconstruct
# Adding op '615' of type const
# Converting op 616 : listconstruct
# Adding op '616' of type const
# Converting op 617 : listconstruct
# Adding op '617' of type const
# Converting op input.171 : _convolution
# Adding op 'input.171' of type conv
# Adding op 'input.171_pad_type_0' of type const
# Adding op 'input.171_pad_0' of type const
# Converting op input.173 : silu_
# Adding op 'input.173' of type silu
# Converting op 623 : listconstruct
# Adding op '623' of type const
# Converting op 624 : listconstruct
# Adding op '624' of type const
# Converting op 625 : listconstruct
# Adding op '625' of type const
# Converting op 626 : listconstruct
# Adding op '626' of type const
# Converting op input.175 : _convolution
# Adding op 'input.175' of type conv
# Adding op 'input.175_pad_type_0' of type const
# Adding op 'input.175_pad_0' of type const
# Converting op 628 : silu_
# Adding op '628' of type silu
# Converting op 632 : listconstruct
# Adding op '632' of type const
# Converting op 633 : listconstruct
# Adding op '633' of type const
# Converting op 634 : listconstruct
# Adding op '634' of type const
# Converting op 635 : listconstruct
# Adding op '635' of type const
# Converting op input.177 : _convolution
# Adding op 'input.177' of type conv
# Adding op 'input.177_pad_type_0' of type const
# Adding op 'input.177_pad_0' of type const
# Converting op 637 : silu_
# Adding op '637' of type silu
# Converting op 638 : listconstruct
# Converting op input.179 : cat
# Adding op 'input.179' of type concat
# Adding op 'input.179_interleave_0' of type const
# Converting op 643 : listconstruct
# Adding op '643' of type const
# Converting op 644 : listconstruct
# Adding op '644' of type const
# Converting op 645 : listconstruct
# Adding op '645' of type const
# Converting op 646 : listconstruct
# Adding op '646' of type const
# Converting op input.181 : _convolution
# Adding op 'input.181' of type conv
# Adding op 'input.181_pad_type_0' of type const
# Adding op 'input.181_pad_0' of type const
# Converting op input.183 : silu_
# Adding op 'input.183' of type silu
# Converting Frontend ==> MIL Ops:  66%|██▋ | 411/620 [00:00<00:00, 2332.09 ops/s]Converting op 649 : constant
# Adding op '649' of type const
# Converting op 650 : constant
# Adding op '650' of type const
# Converting op 651 : constant
# Adding op '651' of type const
# Converting op 652 : constant
# Adding op '652' of type const
# Converting op 653 : constant
# Adding op '653' of type const
# Converting op 657 : listconstruct
# Adding op '657' of type const
# Converting op 658 : listconstruct
# Adding op '658' of type const
# Converting op 659 : listconstruct
# Adding op '659' of type const
# Converting op 660 : listconstruct
# Adding op '660' of type const
# Converting op input.185 : _convolution
# Adding op 'input.185' of type conv
# Adding op 'input.185_pad_type_0' of type const
# Adding op 'input.185_pad_0' of type const
# Converting op 662 : silu_
# Adding op '662' of type silu
# Converting op 663 : constant
# Adding op '663' of type const
# Converting op 664 : listconstruct
# Converting op input.187 : cat
# Adding op 'input.187' of type concat
# Adding op 'input.187_interleave_0' of type const
# Converting op 666 : constant
# Adding op '666' of type const
# Converting op 667 : constant
# Adding op '667' of type const
# Converting op 668 : constant
# Adding op '668' of type const
# Converting op 669 : constant
# Adding op '669' of type const
# Converting op 677 : listconstruct
# Adding op '677' of type const
# Converting op 678 : listconstruct
# Adding op '678' of type const
# Converting op 679 : listconstruct
# Adding op '679' of type const
# Converting op 680 : listconstruct
# Adding op '680' of type const
# Converting op input.189 : _convolution
# Adding op 'input.189' of type conv
# Adding op 'input.189_pad_type_0' of type const
# Adding op 'input.189_pad_0' of type const
# Converting op input.191 : silu_
# Adding op 'input.191' of type silu
# Converting op 689 : listconstruct
# Adding op '689' of type const
# Converting op 690 : listconstruct
# Adding op '690' of type const
# Converting op 691 : listconstruct
# Adding op '691' of type const
# Converting op 692 : listconstruct
# Adding op '692' of type const
# Converting op input.193 : _convolution
# Adding op 'input.193' of type conv
# Adding op 'input.193_pad_type_0' of type const
# Adding op 'input.193_pad_0' of type const
# Converting op input.195 : silu_
# Adding op 'input.195' of type silu
# Converting op 698 : listconstruct
# Adding op '698' of type const
# Converting op 699 : listconstruct
# Adding op '699' of type const
# Converting op 700 : listconstruct
# Adding op '700' of type const
# Converting op 701 : listconstruct
# Adding op '701' of type const
# Converting op input.197 : _convolution
# Adding op 'input.197' of type conv
# Adding op 'input.197_pad_type_0' of type const
# Adding op 'input.197_pad_0' of type const
# Converting op 703 : silu_
# Adding op '703' of type silu
# Converting op 707 : listconstruct
# Adding op '707' of type const
# Converting op 708 : listconstruct
# Adding op '708' of type const
# Converting op 709 : listconstruct
# Adding op '709' of type const
# Converting op 710 : listconstruct
# Adding op '710' of type const
# Converting op input.199 : _convolution
# Adding op 'input.199' of type conv
# Adding op 'input.199_pad_type_0' of type const
# Adding op 'input.199_pad_0' of type const
# Converting op 712 : silu_
# Adding op '712' of type silu
# Converting op 713 : listconstruct
# Converting op input.201 : cat
# Adding op 'input.201' of type concat
# Adding op 'input.201_interleave_0' of type const
# Converting op 718 : listconstruct
# Adding op '718' of type const
# Converting op 719 : listconstruct
# Adding op '719' of type const
# Converting op 720 : listconstruct
# Adding op '720' of type const
# Converting op 721 : listconstruct
# Adding op '721' of type const
# Converting op input.203 : _convolution
# Adding op 'input.203' of type conv
# Adding op 'input.203_pad_type_0' of type const
# Adding op 'input.203_pad_0' of type const
# Converting op input.205 : silu_
# Adding op 'input.205' of type silu
# Converting op 724 : constant
# Adding op '724' of type const
# Converting op 725 : constant
# Adding op '725' of type const
# Converting op 726 : constant
# Adding op '726' of type const
# Converting op 727 : constant
# Adding op '727' of type const
# Converting op 728 : constant
# Adding op '728' of type const
# Converting op 732 : listconstruct
# Adding op '732' of type const
# Converting op 733 : listconstruct
# Adding op '733' of type const
# Converting op 734 : listconstruct
# Adding op '734' of type const
# Converting op 735 : listconstruct
# Adding op '735' of type const
# Converting op input.207 : _convolution
# Adding op 'input.207' of type conv
# Adding op 'input.207_pad_type_0' of type const
# Adding op 'input.207_pad_0' of type const
# Converting op 737 : silu_
# Adding op '737' of type silu
# Converting op 738 : constant
# Adding op '738' of type const
# Converting op 739 : listconstruct
# Converting op input.209 : cat
# Adding op 'input.209' of type concat
# Adding op 'input.209_interleave_0' of type const
# Converting op 741 : constant
# Adding op '741' of type const
# Converting op 742 : constant
# Adding op '742' of type const
# Converting op 743 : constant
# Adding op '743' of type const
# Converting op 744 : constant
# Adding op '744' of type const
# Converting op 752 : listconstruct
# Adding op '752' of type const
# Converting op 753 : listconstruct
# Adding op '753' of type const
# Converting op 754 : listconstruct
# Adding op '754' of type const
# Converting op 755 : listconstruct
# Adding op '755' of type const
# Converting op input.211 : _convolution
# Adding op 'input.211' of type conv
# Adding op 'input.211_pad_type_0' of type const
# Adding op 'input.211_pad_0' of type const
# Converting op input.213 : silu_
# Adding op 'input.213' of type silu
# Converting op 764 : listconstruct
# Adding op '764' of type const
# Converting op 765 : listconstruct
# Adding op '765' of type const
# Converting op 766 : listconstruct
# Adding op '766' of type const
# Converting op 767 : listconstruct
# Adding op '767' of type const
# Converting op input.215 : _convolution
# Adding op 'input.215' of type conv
# Adding op 'input.215_pad_type_0' of type const
# Adding op 'input.215_pad_0' of type const
# Converting op input.217 : silu_
# Adding op 'input.217' of type silu
# Converting op 773 : listconstruct
# Adding op '773' of type const
# Converting op 774 : listconstruct
# Adding op '774' of type const
# Converting op 775 : listconstruct
# Adding op '775' of type const
# Converting op 776 : listconstruct
# Adding op '776' of type const
# Converting op input.219 : _convolution
# Adding op 'input.219' of type conv
# Adding op 'input.219_pad_type_0' of type const
# Adding op 'input.219_pad_0' of type const
# Converting op 778 : silu_
# Adding op '778' of type silu
# Converting op 782 : listconstruct
# Adding op '782' of type const
# Converting op 783 : listconstruct
# Adding op '783' of type const
# Converting op 784 : listconstruct
# Adding op '784' of type const
# Converting op 785 : listconstruct
# Adding op '785' of type const
# Converting op input.221 : _convolution
# Adding op 'input.221' of type conv
# Adding op 'input.221_pad_type_0' of type const
# Adding op 'input.221_pad_0' of type const
# Converting op 787 : silu_
# Adding op '787' of type silu
# Converting op 788 : listconstruct
# Converting op input.223 : cat
# Adding op 'input.223' of type concat
# Adding op 'input.223_interleave_0' of type const
# Converting op 793 : listconstruct
# Adding op '793' of type const
# Converting op 794 : listconstruct
# Adding op '794' of type const
# Converting op 795 : listconstruct
# Adding op '795' of type const
# Converting op 796 : listconstruct
# Adding op '796' of type const
# Converting op input.225 : _convolution
# Adding op 'input.225' of type conv
# Adding op 'input.225_pad_type_0' of type const
# Adding op 'input.225_pad_0' of type const
# Converting op input : silu_
# Adding op 'input' of type silu
# Converting op 799 : constant
# Adding op '799' of type const
# Converting op 800 : constant
# Adding op '800' of type const
# Converting op 801 : constant
# Adding op '801' of type const
# Converting op 802 : constant
# Adding op '802' of type const
# Converting op 803 : constant
# Adding op '803' of type const
# Converting op 804 : constant
# Adding op '804' of type const
# Converting op 805 : constant
# Adding op '805' of type const
# Converting op 806 : constant
# Adding op '806' of type const
# Converting op 807 : constant
# Adding op '807' of type const
# ...
# Adding op '900' of type reshape
# Converting op 901 : listconstruct
# Adding op '901' of type const
# Converting op 902 : permute
# Adding op '902' of type transpose
# Converting op 903 : contiguous
# Setting pytorch op:   %903 = contiguous[](%902, %812) to no-op.
# Converting op 904 : sigmoid
# Adding op '904' of type sigmoid
# Converting op 905 : listconstruct
# Adding op '905' of type const
# Converting op 906 : split_with_sizes
# Adding op '906' of type split
# Adding op '906_axis_0' of type const
# Converting op xy.9 : listunpack
# Converting op 910 : constant
# Adding op '910' of type const
# Converting op 911 : mul
# Adding op '911' of type mul
# Converting op 912 : add
# Adding op '912' of type add
# Converting op 913 : select
# Adding op '913' of type slice_by_index
# Adding op '913_begin_0' of type const
# Adding op '913_end_0' of type const
# Adding op '913_end_mask_0' of type const
# Adding op '913_squeeze_mask_0' of type const
# Converting op xy : mul
# Adding op 'xy' of type mul
# Converting op 915 : constant
# Adding op '915' of type const
# Converting op 916 : mul
# Adding op '916' of type mul
# Converting op 917 : pow
# Adding op '917' of type pow
# Converting op wh : mul
# Adding op 'wh' of type mul
# Converting op 919 : listconstruct
# Converting op y : cat
# Adding op 'y' of type concat
# Adding op 'y_interleave_0' of type const
# Converting op 921 : listconstruct
# Adding op '921' of type const
# Converting op 922 : view
# Adding op 'cast_5' of type cast
# Adding op 'cast_5_dtype_0' of type const
# Adding op '922' of type reshape
# Converting op 923 : listconstruct
# Converting op 924 : cat
# Adding op '924' of type concat
# Adding op '924_interleave_0' of type const
# Converting Frontend ==> MIL Ops: 100%|███▉| 618/620 [00:00<00:00, 1840.60 ops/s]
# Performing passes for torch frontend: "common::dead_code_elimination"
# Removing op "const_8" (type: const)
# Removing op "898_shape" (type: shape)
# Removing op "const_7" (type: const)
# Removing op "897_shape" (type: shape)
# Removing op "const_6" (type: const)
# Removing op "896_shape" (type: shape)
# Removing op "894" (type: const)
# Removing op "892" (type: const)
# Removing op "const_5" (type: const)
# Removing op "864_shape" (type: shape)
# Removing op "const_4" (type: const)
# Removing op "863_shape" (type: shape)
# Removing op "const_3" (type: const)
# Removing op "862_shape" (type: shape)
# Removing op "860" (type: const)
# Removing op "858" (type: const)
# Removing op "const_2" (type: const)
# Removing op "830_shape" (type: shape)
# Removing op "const_1" (type: const)
# Removing op "829_shape" (type: shape)
# Removing op "const_0" (type: const)
# Removing op "828_shape" (type: shape)
# Removing op "826" (type: const)
# Removing op "824" (type: const)
# Removing op "814" (type: const)
# Removing op "813" (type: const)
# Removing op "812" (type: const)
# Removing op "809" (type: const)
# Removing op "808" (type: const)
# Removing op "803" (type: const)
# Removing op "796" (type: const)
# Removing op "794" (type: const)
# Removing op "785" (type: const)
# Removing op "783" (type: const)
# Removing op "776" (type: const)
# Removing op "774" (type: const)
# Removing op "767" (type: const)
# Removing op "765" (type: const)
# Removing op "755" (type: const)
# Removing op "753" (type: const)
# Removing op "743" (type: const)
# Removing op "742" (type: const)
# Removing op "741" (type: const)
# Removing op "735" (type: const)
# Removing op "733" (type: const)
# Removing op "728" (type: const)
# Removing op "727" (type: const)
# Removing op "726" (type: const)
# Removing op "724" (type: const)
# Removing op "721" (type: const)
# Removing op "719" (type: const)
# Removing op "710" (type: const)
# Removing op "708" (type: const)
# Removing op "701" (type: const)
# Removing op "699" (type: const)
# Removing op "692" (type: const)
# Removing op "690" (type: const)
# Removing op "680" (type: const)
# Removing op "678" (type: const)
# Removing op "668" (type: const)
# Removing op "667" (type: const)
# Removing op "666" (type: const)
# Removing op "660" (type: const)
# Removing op "658" (type: const)
# Removing op "653" (type: const)
# Removing op "652" (type: const)
# Removing op "651" (type: const)
# Removing op "649" (type: const)
# Removing op "646" (type: const)
# Removing op "644" (type: const)
# Removing op "635" (type: const)
# Removing op "633" (type: const)
# Removing op "626" (type: const)
# Removing op "624" (type: const)
# Removing op "617" (type: const)
# Removing op "615" (type: const)
# Removing op "605" (type: const)
# Removing op "603" (type: const)
# Removing op "593" (type: const)
# Removing op "592" (type: const)
# Removing op "591" (type: const)
# Removing op "586" (type: const)
# Removing op "584" (type: const)
# Removing op "581" (type: const)
# Removing op "579" (type: const)
# Removing op "574" (type: const)
# Removing op "573" (type: const)
# Removing op "572" (type: const)
# Removing op "568" (type: const)
# Removing op "566" (type: const)
# Removing op "557" (type: const)
# Removing op "555" (type: const)
# Removing op "548" (type: const)
# Removing op "546" (type: const)
# Removing op "539" (type: const)
# Removing op "537" (type: const)
# Removing op "527" (type: const)
# Removing op "525" (type: const)
# Removing op "515" (type: const)
# Removing op "514" (type: const)
# Removing op "513" (type: const)
# Removing op "508" (type: const)
# Removing op "506" (type: const)
# Removing op "503" (type: const)
# Removing op "501" (type: const)
# Removing op "496" (type: const)
# Removing op "495" (type: const)
# Removing op "494" (type: const)
# Removing op "490" (type: const)
# Removing op "488" (type: const)
# Removing op "479" (type: const)
# Removing op "477" (type: const)
# Removing op "470" (type: const)
# Removing op "468" (type: const)
# Removing op "461" (type: const)
# Removing op "459" (type: const)
# Removing op "449" (type: const)
# Removing op "447" (type: const)
# Removing op "437" (type: const)
# Removing op "436" (type: const)
# Removing op "435" (type: const)
# Removing op "432" (type: const)
# Removing op "430" (type: const)
# Removing op "422" (type: const)
# Removing op "421" (type: const)
# Removing op "417" (type: const)
# Removing op "416" (type: const)
# Removing op "412" (type: const)
# Removing op "411" (type: const)
# Removing op "406" (type: const)
# Removing op "404" (type: const)
# Removing op "396" (type: const)
# Removing op "395" (type: const)
# Removing op "394" (type: const)
# Removing op "393" (type: const)
# Removing op "392" (type: const)
# Removing op "391" (type: const)
# Removing op "390" (type: const)
# Removing op "389" (type: const)
# Removing op "388" (type: const)
# Removing op "385" (type: const)
# Removing op "383" (type: const)
# Removing op "378" (type: const)
# Removing op "377" (type: const)
# Removing op "376" (type: const)
# Removing op "374" (type: const)
# Removing op "371" (type: const)
# Removing op "369" (type: const)
# Removing op "360" (type: const)
# Removing op "358" (type: const)
# Removing op "350" (type: const)
# Removing op "348" (type: const)
# Removing op "341" (type: const)
# Removing op "339" (type: const)
# Removing op "329" (type: const)
# Removing op "327" (type: const)
# Removing op "320" (type: const)
# Removing op "318" (type: const)
# Removing op "308" (type: const)
# Removing op "306" (type: const)
# Removing op "299" (type: const)
# Removing op "297" (type: const)
# Removing op "285" (type: const)
# Removing op "283" (type: const)
# Removing op "273" (type: const)
# Removing op "272" (type: const)
# Removing op "271" (type: const)
# Removing op "268" (type: const)
# Removing op "266" (type: const)
# Removing op "261" (type: const)
# Removing op "260" (type: const)
# Removing op "259" (type: const)
# Removing op "257" (type: const)
# Removing op "254" (type: const)
# Removing op "252" (type: const)
# Removing op "243" (type: const)
# Removing op "241" (type: const)
# Removing op "233" (type: const)
# Removing op "231" (type: const)
# Removing op "224" (type: const)
# Removing op "222" (type: const)
# Removing op "212" (type: const)
# Removing op "210" (type: const)
# Removing op "203" (type: const)
# Removing op "201" (type: const)
# Removing op "191" (type: const)
# Removing op "189" (type: const)
# Removing op "182" (type: const)
# Removing op "180" (type: const)
# Removing op "168" (type: const)
# Removing op "166" (type: const)
# Removing op "156" (type: const)
# Removing op "155" (type: const)
# Removing op "154" (type: const)
# Removing op "151" (type: const)
# Removing op "149" (type: const)
# Removing op "144" (type: const)
# Removing op "143" (type: const)
# Removing op "142" (type: const)
# Removing op "140" (type: const)
# Removing op "137" (type: const)
# Removing op "135" (type: const)
# Removing op "126" (type: const)
# Removing op "124" (type: const)
# Removing op "116" (type: const)
# Removing op "114" (type: const)
# Removing op "107" (type: const)
# Removing op "105" (type: const)
# Removing op "95" (type: const)
# Removing op "93" (type: const)
# Removing op "83" (type: const)
# Removing op "82" (type: const)
# Removing op "81" (type: const)
# Removing op "78" (type: const)
# Removing op "76" (type: const)
# Removing op "71" (type: const)
# Removing op "70" (type: const)
# Removing op "69" (type: const)
# Removing op "67" (type: const)
# Removing op "64" (type: const)
# Removing op "62" (type: const)
# Removing op "46" (type: const)
# Removing op "45" (type: const)
# Removing op "43" (type: const)
# Removing op "41" (type: const)
# Removing op "40" (type: const)
# Performing passes for torch frontend: "common::loop_invariant_elimination"
# Performing passes for torch frontend: "common::dead_code_elimination"
# Performing passes for torch frontend: "torch::torch_upsample_to_core_upsample"
# Performing passes for torch frontend: "torch::torch_tensor_assign_to_core"
# Running MIL Common passes:   0%|                    | 0/34 [00:00<?, ? passes/s]Performing pass: "common::cast_optimization"
# Performing pass: "common::const_elimination"
# Adding op '845' of type const
# Adding op '879' of type const
# Adding op '913' of type const
# Performing pass: "common::sanitize_input_output_names"
# /Users/vdausmann/pytorch-test/env/lib/python3.8/site-packages/coremltools/converters/mil/mil/passes/name_sanitization_utils.py:129: UserWarning: Output, '924', of the source model, has been renamed to 'var_924' in the Core ML model.
#   warnings.warn(msg.format(var.name, new_name))
# Performing pass: "common::divide_to_multiply"
# Performing pass: "common::add_conv_transpose_output_shape"
# Performing pass: "common::const_elimination"
# Performing pass: "common::loop_invariant_elimination"
# Performing pass: "common::remove_symbolic_reshape"
# remove_symbolic_reshape: changed 0 reshapes.
# Performing pass: "common::noop_elimination"
# Performing pass: "common::fuse_matmul_weight_bias"
# Performing pass: "common::fuse_linear_bias"
# Performing pass: "common::fuse_gelu_tanh_approximation"
# Adding op 'pow' of type pow
# Adding op 'pow_y_0' of type const
# Adding op 'mul_1' of type mul
# Adding op 'mul_1_x_0' of type const
# Adding op 'add' of type add
# Adding op 'mul_2' of type mul
# Adding op 'mul_2_x_0' of type const
# Adding op 'tanh' of type tanh
# Adding op 'add_1' of type add
# Adding op 'add_1_x_0' of type const
# Adding op 'mul' of type mul
# Adding op 'mul_x_0' of type const
# Adding op 'mul_3' of type mul
# Adding op 'pow' of type pow
# Adding op 'pow_y_1' of type const
# Adding op 'mul_1' of type mul
# Adding op 'mul_1_x_1' of type const
# Adding op 'add' of type add
# Adding op 'mul_2' of type mul
# Adding op 'mul_2_x_1' of type const
# Adding op 'tanh' of type tanh
# Adding op 'add_1' of type add
# Adding op 'add_1_x_1' of type const
# Adding op 'mul' of type mul
# Adding op 'mul_x_1' of type const
# Adding op 'mul_3' of type mul
# Performing pass: "common::fuse_gelu_exact"
# Performing pass: "common::fuse_leaky_relu"
# Performing pass: "common::rank0_expand_dims_swap"
# Performing pass: "common::use_reflection_padding"
# Performing pass: "common::merge_consecutive_paddings"
# Performing pass: "common::pad_conv_connect"
# Performing pass: "common::image_input_preprocess"
# Performing pass: "common::replace_stack_reshape"
# Performing pass: "common::reduce_transposes"
# Adding op 'identity_0' of type identity
# Performing pass: "common::fuse_conv_scale"
# Performing pass: "common::fuse_conv_bias"
# Performing pass: "common::fuse_onehot_matmul_to_gather"
# Performing pass: "common::fuse_layernorm_or_instancenorm"
# Performing pass: "common::fuse_elementwise_to_batchnorm"
# Performing pass: "common::fuse_reduce_mean"
# Performing pass: "common::fuse_conv_batchnorm"
# Performing pass: "common::fuse_conv_scale"
# Performing pass: "common::fuse_conv_bias"
# Performing pass: "common::detect_concat_interleave"
# Performing pass: "common::concat_to_pixel_shuffle"
# Performing pass: "common::remove_redundant_ops"
# Performing pass: "common::dead_code_elimination"
# Removing op "cast_5_dtype_0" (type: const)
# Removing op "913_squeeze_mask_0" (type: const)
# Removing op "913_end_mask_0" (type: const)
# Removing op "913_end_0" (type: const)
# Removing op "913_begin_0" (type: const)
# Removing op "cast_4_dtype_0" (type: const)
# Removing op "cast_3_dtype_0" (type: const)
# Removing op "879_squeeze_mask_0" (type: const)
# Removing op "879_end_mask_0" (type: const)
# Removing op "879_end_0" (type: const)
# Removing op "879_begin_0" (type: const)
# Removing op "cast_2_dtype_0" (type: const)
# Removing op "cast_1_dtype_0" (type: const)
# Removing op "845_squeeze_mask_0" (type: const)
# Removing op "845_end_mask_0" (type: const)
# Removing op "845_end_0" (type: const)
# Removing op "845_begin_0" (type: const)
# Removing op "cast_0_dtype_0" (type: const)
# Removing op "805" (type: const)
# Removing op "52_stride_0" (type: const)
# Removing op "52_end_mask_0" (type: const)
# Removing op "52_end_0" (type: const)
# Removing op "52_begin_0" (type: const)
# Running MIL Common passes: 100%|██████████| 34/34 [00:00<00:00, 346.86 passes/s]
# Running MIL Clean up passes:   0%|                   | 0/9 [00:00<?, ? passes/s]Performing pass: "common::cast_optimization"
# Performing pass: "common::const_elimination"
# Performing pass: "common::loop_invariant_elimination"
# Performing pass: "common::noop_elimination"
# Performing pass: "common::dedup_op_and_var_names"
# Performing pass: "common::reduce_transposes"
# Adding op 'identity_1' of type identity
# Performing pass: "common::remove_redundant_ops"
# Performing pass: "common::topological_reorder"
# Adding op 'transpose_0' of type transpose
# Adding op 'transpose_1' of type transpose
# Adding op 'transpose_2' of type transpose
# Performing pass: "common::dead_code_elimination"
# Running MIL Clean up passes: 100%|██████████| 9/9 [00:00<00:00, 121.55 passes/s]
# Performing passes for nn_backend: "nn_backend::commingle_loop_vars"
# Performing passes for nn_backend: "nn_backend::handle_return_inputs_as_outputs"
# Performing passes for nn_backend: "common::const_elimination"
# Performing passes for nn_backend: "common::dead_code_elimination"
# Performing passes for nn_backend: "nn_backend::handle_unused_inputs"
# Performing passes for nn_backend: "nn_backend::alert_return_type_cast"
# Translating MIL ==> NeuralNetwork Ops:  79%|▊| 539/683 [00:00<00:00, 1236.46 opsadded const 806 for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x36d12e850>
# added const 804 for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x36d12e850>
# added const 802 for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x36d12e850>
# added const 801 for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x36d12e850>
# Translating MIL ==> NeuralNetwork Ops:  98%|▉| 668/683 [00:01<00:00, 507.05 ops/added const 800 for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x36d12e850>
# added const 799 for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x36d12e850>
# Translating MIL ==> NeuralNetwork Ops: 100%|█| 683/683 [00:01<00:00, 657.71 ops/
# CoreML: export success ✅ 63.8s, saved as best_colab_yolo5s_peru.mlmodel (51.5 MB)
#
# Export complete (79.6s)
# Results saved to /Users/vdausmann/pytorch-test/yolov5
# Detect:          python detect.py --weights best_colab_yolo5s_peru.mlmodel
# Validate:        python val.py --weights best_colab_yolo5s_peru.mlmodel
# PyTorch Hub:     model = torch.hub.load('ultralytics/yolov5', 'custom', 'best_colab_yolo5s_peru.mlmodel')
# Visualize:       https://netron.app

# %% [markdown]
# 1. Rename the dataset and find duplicate images (buffer error) in the Dataset. Rename using the buggy script called "Rename_and_pressure_correct", pay attention to the order of directories in the image rootfolder and if all profiles end with a file that has a pressure value >0 (out of index error). Remove all duplicate images (I did it with Duplicate File finder for MacOS).

# %% [markdown]
# 2. Here comes the function that extracts the information after detection. (Will be used after detection, but has to be defined here)

# %%
import csv
import cv2 as cv
import numpy as np
import os

def get_object_info(file_path, result_path, txt_path):

    pixel_square = (13.5*10**-3)**2 #in mm

    def find_object(img):
        """Finds the largest object and computes the esd.
        Args:
            img (np.array): gray scale image
        Returns:
            ESD: 2 * sqrt(Area / PI)
        """
        max_val = np.mean(img) - np.std(img)

        img_c = img.copy()
        img_c[np.where(img < max_val)] = 255
        img_c[np.where(img >= max_val)] = 0
        img = img_c
        thresh = img
        # thresh = cv.threshold(img, max_val, 255, cv.THRESH_BINARY)[1]

        cnts = cv.findContours(thresh, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)[0]
        cnt_areas = {cv.contourArea(cnt): cnt for cnt in cnts}
        if cnt_areas:
            cnt_areas_list = list(cnt_areas)
            cnt_areas_list.sort()
            max_area = cnt_areas_list[-1]
            esd = 2 * np.sqrt(max_area / np.pi)
            return esd, max_area
        else:
            return 0

    fns = sorted(os.listdir(file_path))
    result_path = result_path
    txt_path = txt_path
    info = []
    fileinfo = []

    for fn_r in fns:
        counter = 0
        bounding_info = []
        img_mass = []
        img_mass2 = []
        img_esd = []
        txtfn = os.path.join(txt_path, fn_r[:-4])
        fn = os.path.join(file_path, fn_r)
        fn, ending = fn[:-4], fn[-4:]
        
        try:
            pos = fn.find('bar')
            try:
                press = float(fn[pos-5:pos])
                depth = (press-1)/0.1
            except ValueError:
                press = float(fn[pos-4:pos])
                depth = (press-1)/0.1
        except:
            continue
            
        #print(txtfn)
        if ending == ".jpg" or ending == ".tif" or ending == ".png":
            img = cv.imread(fn + ending)
            try:
                with open(txtfn + '.txt') as file:
                    for line in file:
                        d=[]
                        for i in (line.rstrip()).split(' '):
                            d.append(float(i))
                        bounding_info.append(d)
                #print('found: ' + fn +'.txt')
            except:
                continue
            img_h, img_w = img.shape[:2]

            for bbox in bounding_info:
                counter = counter + 1
                instclass, rel_x, rel_y, rel_w, rel_h, conf = bbox
                c_x = round(rel_x * img_w)  #x-position of center
                c_y = round(rel_y * img_h)  #y-position of center
                w = round(rel_w * img_w)
                h = round(rel_h * img_h)
                x = c_x - w // 2            #x-position of top-left corner
                y = c_y - h // 2            #y-position of top-left corner

                crop = img[y:y+h, x:x+w]
                
                gray = cv.cvtColor(crop, cv.COLOR_BGR2GRAY)
                esd,p_area = find_object(gray)
                biovolume = (np.pi*(esd * 13.5 * 10**-4)**3)/6 #in cubic centimeters
                biomass_vol =  biovolume * 1.060  #biomass calculation from sphere volume derived from ESD, with a density of 1.060 g cm-3
                #area = np.pi*((esd * 13.5 * 10**-3)/2)**2 #area of the ESD in square millimeters
                area= p_area*pixel_square
                biomass_area = 43.97*(area**1.52)*0.48 #according to Lahette et al. 2009, dry weight to biomass C conversion following Kiorboe et al 2013
                img_esd.append(esd)
                img_mass.append(biomass_vol)
                img_mass2.append(biomass_area)
                info.append([fn, counter, c_x, c_y, w, h, x, y, esd, instclass, conf, depth, biomass_vol, biomass_area])
            
            sum_esd = 0
            for i in range(counter):
                sum_esd=sum_esd+img_esd[i]
            meanESD = sum_esd/counter

            sum_bio = 0
            for i in range(counter):
                sum_bio=sum_bio+img_mass[i]
            total_biomass = sum_bio

            sum_bio2 = 0
            for i in range(counter):
                sum_bio2=sum_bio2+img_mass2[i]
            total_biomass2 = sum_bio2

            fileinfo.append([fn_r,fn_r[24:32],fn_r[33:39],fn_r[16:18],depth,counter,meanESD*13.5,total_biomass,total_biomass2])

    with open(result_path + '_detailed.csv', "w", newline="") as f:
        writer = csv.writer(f, delimiter=";")
        writer.writerow(["Filename", "ID", "Center x in px", "Center y in px", "Width in px", "Height in px", "x in px", "y in px", "ESD in px", "class", "confidence", "depth in meters below surface", "biomass in g(C) using volume", "biomass in ug(C) after Lahette 2009"])
        for row in info:
            writer.writerow(row)    
    with open(result_path + '_overview.csv', "w", newline="") as f:
        writer = csv.writer(f, delimiter=";")
        writer.writerow(["Filename", "Sampling day", "local time", "Mesocosm-#", "depth in meters below surface", "Copepod-#", "mean-ESD in um", "Biomass in g(C) using Volume", "Biomass in ug(C) after Lahette 2009"])
        for row in fileinfo:
            writer.writerow(row)

# %% [markdown]
# 3. Start detection using the right images as source, the results will be in /runs/detect/exp.../:

# %%
#define the folders containing all images and where the detection information is stored
rootfolder = '/Users/vdausmann/yolo/datasets/PIScO_Peru_source'
#destfolder = 
for dayfolder in os.listdir(rootfolder):
    print(dayfolder)
    if os.path.isdir(rootfolder+'/'+dayfolder):
        for meso in os.listdir(rootfolder+'/'+dayfolder):
            print(meso)
            mesodir = rootfolder+'/'+dayfolder+'/'+meso
            if os.path.isdir(mesodir):
                print(mesodir)
                # !python detect.py --weights best_colab_yolo5s_peru.mlmodel --source {mesodir} --img 5120 --data data.yaml --save-txt --save-crop --save-conf --nosave --conf-thres 0.4 --name {mesodir[-13:]} 
                IMG_PATH = mesodir
                TXT_PATH = os.path.join(detect_dir, dayfolder, meso)
                RESULT_PATH = os.path.join(detect_dir, 'results', dayfolder, meso)
                get_object_info(IMG_PATH, RESULT_PATH, TXT_PATH)
            else:
                pass
    else:
        pass

# %%
# !python val.py --data data.yaml --weights best_colab_yolo5s_peru.mlmodel --conf-thres 0.4
# Out:
# val: data=data.yaml, weights=['best_colab_yolo5s_peru.mlmodel'], batch_size=32, imgsz=640, conf_thres=0.4, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING: confidence threshold 0.4 > 0.001 produces invalid results ⚠️
# YOLOv5 🚀 v6.1-246-g2dd3db0 Python-3.8.13 torch-1.13.0.dev20220607 CPU
#
# Loading best_colab_yolo5s_peru.mlmodel for CoreML inference...
# TensorFlow version 2.9.2 has not been tested with coremltools. You may run into unexpected errors. TensorFlow 2.6.2 is the most recent version that has been tested.
# Keras version 2.9.0 has not been tested with coremltools. You may run into unexpected errors. Keras 2.6.0 is the most recent version that has been tested.
# Torch version 1.13.0.dev20220607 has not been tested with coremltools. You may run into unexpected errors. Torch 1.10.2 is the most recent version that has been tested.
# Forcing --batch-size 1 square inference (1,3,640,640) for non-PyTorch models
# val: Scanning '/Users/vdausmann/pytorch-test/yolov5/../test/labels' images and l
# val: New cache created: /Users/vdausmann/pytorch-test/yolov5/../test/labels.cache
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        551       1122      0.732      0.725      0.721      0.298
#              Copepod        551       1122      0.732      0.725      0.721      0.298
# Speed: 0.4ms pre-process, 37.4ms inference, 0.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/val/exp3

# %% [markdown]
# 4. The detection results will be translated into the desired form, with the calculation of object ESD and biomass (following XXX):

# %%
#rootfolder = '/Users/vdausmann/yolo/datasets/PIScO_Peru_source'
rootfolder = '/Volumes/Extreme Pro/PIScO_Peru_source'

#detect_dir = '/Users/vdausmann/pytorch-test/yolov5/runs/detect/PIScO_Peru_detected+summary'
detect_dir = '/Users/vdausmann/pytorch-test/yolov5/runs/detect/PIScO_Peru_detected_not_yet_analysed'

result_dir = os.path.join(detect_dir,'results')
if not os.path.exists(result_dir):
    os.mkdir(result_dir)

for dayfolder in os.listdir(detect_dir):
    daydir = os.path.join(detect_dir,dayfolder)
    if os.path.isdir(daydir):
        for meso in os.listdir(daydir):
            mesodir = os.path.join(rootfolder,dayfolder,meso)
            if os.path.isdir(mesodir):
                #print(mesodir)
                print('processing ...'+dayfolder+' '+meso)
                IMG_PATH = mesodir
                TXT_PATH = os.path.join(detect_dir, dayfolder, meso, 'labels')
                #print(TXT_PATH)
                if not os.path.exists(os.path.join(result_dir, dayfolder)):
                    os.mkdir(os.path.join(result_dir, dayfolder))   
                RESULT_PATH = os.path.join(result_dir, dayfolder, meso) 
                #print(RESULT_PATH)            
                get_object_info(IMG_PATH, RESULT_PATH, TXT_PATH)
            else:
                pass
    else:
        pass
# Out:
# processing ...13_03_2020 M7

# %%
#test
rootfolder = '/Volumes/Elements/PIScO_Peru_cleaned'
os.listdir(rootfolder)
# Out:
# ['.DS_Store',
#  '01_03_2020',
#  '03_03_2020',
#  '05_03_2020',
#  '07_03_2020',
#  '09_03_2020',
#  '11_03_2020',
#  '13_03_2020']

# %% [markdown]
# 5. Plotting results:
#
# This will plot the following figures:
#
# Per day, for all mesocosms:
# - Depth vs copepod-counts
# - Depth vs equvialent spherical diameter (ESD)
# - Depth vs biomass formula
#
#
# For each mesocosm:
# - Copepod-# vs depth over time
# - ESD vs depth over time
# - Biomass vs depth over time
#
# - Sum of #,ESD, Biomass over time
#
# - Average of #,ESD, Biomass per depth over time
#
# - Concentration per liter per day
#
# Differences:
# ESD LL vs HL
# Normalized against PA -> DW%
# Size top vs bottom

# %%
# !python detect.py --weights best_colab_yolo5s_peru.mlmodel --source '/Users/vdausmann/yolo/datasets/CUSCO-Peru-2020_M6_PISCO20200323_133905.7300_1.688bar.tif' --img 5120 --data data.yaml --conf-thres 0.4
# Out:
# detect: weights=['best_colab_yolo5s_peru.mlmodel'], source=/Users/vdausmann/yolo/datasets/CUSCO-Peru-2020_M6_PISCO20200323_133905.7300_1.688bar.tif, data=data.yaml, imgsz=[5120, 5120], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-80-g55b0096 Python-3.8.13 torch-1.13.0.dev20220831 CPU
#
# Loading best_colab_yolo5s_peru.mlmodel for CoreML inference...
# TensorFlow version 2.9.2 has not been tested with coremltools. You may run into unexpected errors. TensorFlow 2.6.2 is the most recent version that has been tested.
# Keras version 2.9.0 has not been tested with coremltools. You may run into unexpected errors. Keras 2.6.0 is the most recent version that has been tested.
# Torch version 1.13.0.dev20220831 has not been tested with coremltools. You may run into unexpected errors. Torch 1.10.2 is the most recent version that has been tested.
# image 1/1 /Users/vdausmann/yolo/datasets/CUSCO-Peru-2020_M6_PISCO20200323_133905.7300_1.688bar.tif: 5120x5120 144 Copepods, 2493.3ms
# Speed: 19.6ms pre-process, 2493.3ms inference, 8.3ms NMS per image at shape (1, 3, 5120, 5120)
# Results saved to runs/detect/exp12
